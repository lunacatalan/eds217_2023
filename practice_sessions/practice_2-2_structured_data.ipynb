# %% [markdown]
# | [⬅️ Previous Session](practice_2-1_control_flow_statements.ipynb) | [🏠 Course Home](../index.ipynb) | [➡️ Next Session](practice_3-1_numpy.ipynb) |
#
# # Practice 1-4: Structured Data in Python

# %% [markdown]
# ## 📚  <b> Practice 1. </b>
#
# Dictionaries are an extremely common data structure. Often data is easiest to store according to keys, where each row of data has a unique key.
#
# For example, a dictionary of students might have a key for each student's name or id, and then a set of values that are associated with that student.
#
# ### Make a dictionary of your peers.
#
# Come up with 3-4 questions and ask 5-6 of your peers to give answers to each one. The questions can be anything you want, but they should be questions that can be answered with a single word or number.
#
# For example, you might ask:
# - What is your favorite color? (pretty weak question)
# - How many siblings do you have? (ok, but not great)
# - What is your favorite genre of film? (better)
# - On a scale of 1-10, how well do you feel that you understand python dictionaries? (better still)
#
# Make sure you have a key for each person, and then a set of values for each question.
#
# Based on each person's responses, build a dictionary in the cell below:
#
# (note: You will end up with a dictionary of dictionaries)
#
# ```python
# # Example:
# my_dict = {
#     'person1': {
#         'question1': 'answer1',
#         'question2': 'answer2',
#         'question3': 'answer3',
#         'question4': 'answer4',
#     },
#     'person2': {
#         'question1': 'answer1',
#         'question2': 'answer2',
#         'question3': 'answer3',
#         'question4': 'answer4',
#     },
#     'person3': {
#         'question1': 'answer1',
#         'question2': 'answer2',
#         'question3': 'answer3',
#         'question4': 'answer4',
#     },
# }
# ```

# %%
my_dict = {
    'Kate': {
        'If you were a fruit, what would you be?': 'avocado',
        'What place are you from?': 'New Jersey',
        'If you had a superpower what would it be': 'breathe underwater',
        'Whats the grossest thing you would eat?': 'a bug',
        'What would you do first if you woke up as a squirrel': 'climb a tree'
    },
    'Amanda': {
        'If you were a fruit, what would you be?': 'strawberry',
        'What place are you from?': 'Santa Barbara',
        'If you had a superpower what would it be': 'invisiblity',
        'Whats the grossest thing you would eat?': 'snails',
        'What would you do first if you woke up as a squirrel': 'walk across the powerlines'
    },
    'Anna': {
        'If you were a fruit, what would you be?': 'tomato',
        'What place are you from?': 'bay area',
        'If you had a superpower what would it be': 'teleportation',
        'Whats the grossest thing you would eat?': 'snails',
        'What would you do first if you woke up as a squirrel': 'harrass dogs from a tree'
    },
    'Charlie': {
        'If you were a fruit, what would you be?': 'papaya',
        'What place are you from?': 'los angeles',
        'If you had a superpower what would it be': 'underwater',
        'Whats the grossest thing you would eat?': 'backlava that had been dropped in dirt',
        'What would you do first if you woke up as a squirrel': 'climb a tree'
    },
    'Kelly': {
        'If you were a fruit, what would you be?': 'passionfruit',
        'What place are you from?': 'north florida',
        'If you had a superpower what would it be': 'flying',
        'Whats the grossest thing you would eat?': 'cow stomach',
        'What would you do first if you woke up as a squirrel': 'go nuts!'
    },
}

# %% [markdown]
# ## Dictionary to dataframe
#
# Now that you have a dictionary, you can convert it to a dataframe.
#
# ### Convert your dictionary to a dataframe
#
# Use the `pd.DataFrame()` function to convert your dictionary to a dataframe.
#
# ```python
# import pandas as pd
#
# # Convert a dictionary to a dataframe
# df = pd.DataFrame(my_dict)
# ```

# %%
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# convert dictionary to a dataframe 
df = pd.DataFrame(my_dict)

# %% [markdown]
# ### Investigate your dataframe using the following functions:
#
# - `df.head()`
# - `df.tail()`
# - `df.info()`

# %%
df.head()
df.tail()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, If you were a fruit, what would you be? to What would you do first if you woke up as a squirrel
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Kate     5 non-null      object
#  1   Amanda   5 non-null      object
#  2   Anna     5 non-null      object
#  3   Charlie  5 non-null      object
#  4   Kelly    5 non-null      object
# dtypes: object(5)
# memory usage: 240.0+ bytes

# %% [markdown]
# Is your dataframe what you expected? If not, what is different? Why?? How would you need to change your data structure to get the dataframe you expected?

# %%
# I would need to flip it so that the names are the rows

# %% [markdown]
# `df.transpose()` might be helpful here. What does it do?
# create a new dataframe that is a transposed version of your original dataframe.
#
# ```python
# # Transpose a dataframe
# df_transposed = df.transpose()
# ```

# %%
# Transpose your dataframe so that the people are the rows and the questions are the columns.
df_transposed = df.transpose()

df_transposed.head()
# Out:
#         If you were a fruit, what would you be? What place are you from?
# Kate                                    avocado               New Jersey  \
# Amanda                               strawberry            Santa Barbara
# Anna                                     tomato                 bay area
# Charlie                                  papaya              los angeles
# Kelly                              passionfruit            north florida
#
#         If you had a superpower what would it be
# Kate                          breathe underwater  \
# Amanda                               invisiblity
# Anna                               teleportation
# Charlie                               underwater
# Kelly                                     flying
#
#         Whats the grossest thing you would eat?
# Kate                                      a bug  \
# Amanda                                   snails
# Anna                                     snails
# Charlie  backlava that had been dropped in dirt
# Kelly                               cow stomach
#
#         What would you do first if you woke up as a squirrel
# Kate                                          climb a tree
# Amanda                          walk across the powerlines
# Anna                              harrass dogs from a tree
# Charlie                                       climb a tree
# Kelly                                             go nuts!

# %% [markdown]
# ### Visualize/summarize your dataframe using one or more of the following functions:
#
# - `df.describe()`
# - `df.plot()`
# - `df.hist()`

# %%
import matplotlib.pyplot as plt


df_transposed.describe()
# Out:
#        If you were a fruit, what would you be? What place are you from?
# count                                        5                        5  \
# unique                                       5                        5
# top                                    avocado               New Jersey
# freq                                         1                        1
#
#        If you had a superpower what would it be
# count                                         5  \
# unique                                        5
# top                          breathe underwater
# freq                                          1
#
#        Whats the grossest thing you would eat?
# count                                        5  \
# unique                                       4
# top                                     snails
# freq                                         2
#
#        What would you do first if you woke up as a squirrel
# count                                                   5
# unique                                                  4
# top                                          climb a tree
# freq                                                    2

# %%
# Out:
#   Cell In[23], line 1
#     df.plot(data: df_transposed,
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 📚  <b> Practice 2. </b>
#
# ### Structured data search: Find structured data on the internet and convert it to a dataframe.
#
# You're looking for data that is in a table format, like a spreadsheet, but not available as an easy to download `.csv` or `.excel` file. This turns out to describe a lot of data!
#
# Often you can find this kind of data on wikipedia, or on government websites, or in research articles that contain tables of results.

# %%
# make dataframe from copy 
df = pd.read_clipboard()
df
# Out:
#     Year Deaths[56]  Number  of  incidents[57]
# 0   1970      2,226     298 NaN            NaN
# 1   1971      2,228     271 NaN            NaN
# 2   1972      3,346     344 NaN            NaN
# 3   1973      2,814     333 NaN            NaN
# 4   1974      2,621     270 NaN            NaN
# 5   1975      1,856     316 NaN            NaN
# 6   1976      2,419     277 NaN            NaN
# 7   1977      2,449     340 NaN            NaN
# 8   1978      2,042     356 NaN            NaN
# 9   1979      2,511     328 NaN            NaN
# 10  1980      2,203     325 NaN            NaN
# 11  1981      1,506     272 NaN            NaN
# 12  1982      1,958     250 NaN            NaN
# 13  1983      1,921     238 NaN            NaN
# 14  1984      1,273     234 NaN            NaN
# 15  1985      2,968     261 NaN            NaN
# 16  1986      1,763     238 NaN            NaN
# 17  1987      2,064     277 NaN            NaN
# 18  1988      2,313     254 NaN            NaN
# 19  1989      2,507     265 NaN            NaN
# 20  1990      1,631     261 NaN            NaN
# 21  1991      1,957     240 NaN            NaN
# 22  1992      2,299     266 NaN            NaN
# 23  1993      1,760     275 NaN            NaN
# 24  1994      2,018     231 NaN            NaN
# 25  1995      1,828     266 NaN            NaN
# 26  1996      2,796     251 NaN            NaN
# 27  1997      1,768     232 NaN            NaN
# 28  1998      1,721     225 NaN            NaN
# 29  1999      1,150     221 NaN            NaN
# 30  2000      1,586     198 NaN            NaN
# 31  2001   1,539[a]     210 NaN            NaN
# 32  2002      1,418     197 NaN            NaN
# 33  2003      1,233     201 NaN            NaN
# 34  2004        767     178 NaN            NaN
# 35  2005      1,463     194 NaN            NaN
# 36  2006      1,298     192 NaN            NaN
# 37  2007        981     169 NaN            NaN
# 38  2008        952     189 NaN            NaN
# 39  2009      1,108     163 NaN            NaN
# 40  2010      1,130     162 NaN            NaN
# 41  2011        828     154 NaN            NaN
# 42  2012        800     156 NaN            NaN
# 43  2013        459     138 NaN            NaN
# 44  2014      1,328     122 NaN            NaN
# 45  2015        898     123 NaN            NaN
# 46  2016        629     102 NaN            NaN
# 47  2017        399     101 NaN            NaN
# 48  2018      1,040     113 NaN            NaN
# 49  2019        578     125 NaN            NaN
# 50  2020        463      90 NaN            NaN
# 51  2021        414     113 NaN            NaN
# 52  2022        357      95 NaN            NaN

# %% [markdown]
# ### Convert your data to a dataframe

# %%
# drop columns by name of column 
df_new = df.drop(['of', 'incidents[57]'], axis=1)

# rename columns 
flight_incidents = df_new.rename(columns={"Deaths[56]": "Deaths", "Number": "Numer of Incidents"})

flight_incidents
# Out:
#     Year    Deaths  Numer of Incidents
# 0   1970     2,226                 298
# 1   1971     2,228                 271
# 2   1972     3,346                 344
# 3   1973     2,814                 333
# 4   1974     2,621                 270
# 5   1975     1,856                 316
# 6   1976     2,419                 277
# 7   1977     2,449                 340
# 8   1978     2,042                 356
# 9   1979     2,511                 328
# 10  1980     2,203                 325
# 11  1981     1,506                 272
# 12  1982     1,958                 250
# 13  1983     1,921                 238
# 14  1984     1,273                 234
# 15  1985     2,968                 261
# 16  1986     1,763                 238
# 17  1987     2,064                 277
# 18  1988     2,313                 254
# 19  1989     2,507                 265
# 20  1990     1,631                 261
# 21  1991     1,957                 240
# 22  1992     2,299                 266
# 23  1993     1,760                 275
# 24  1994     2,018                 231
# 25  1995     1,828                 266
# 26  1996     2,796                 251
# 27  1997     1,768                 232
# 28  1998     1,721                 225
# 29  1999     1,150                 221
# 30  2000     1,586                 198
# 31  2001  1,539[a]                 210
# 32  2002     1,418                 197
# 33  2003     1,233                 201
# 34  2004       767                 178
# 35  2005     1,463                 194
# 36  2006     1,298                 192
# 37  2007       981                 169
# 38  2008       952                 189
# 39  2009     1,108                 163
# 40  2010     1,130                 162
# 41  2011       828                 154
# 42  2012       800                 156
# 43  2013       459                 138
# 44  2014     1,328                 122
# 45  2015       898                 123
# 46  2016       629                 102
# 47  2017       399                 101
# 48  2018     1,040                 113
# 49  2019       578                 125
# 50  2020       463                  90
# 51  2021       414                 113
# 52  2022       357                  95

# %% [markdown]
# ## Explore your dataframe using the following functions:
#
# - `df.describe()`
# - `df.plot()`
# - `df.hist()`

# %%
flight_incidents.describe()
flight_incidents.plot()
flight_incidents.hist()
# Out:
# array([[<Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'Numer of Incidents'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt

plt.plot(flight_incidents['Year'], flight_incidents['Numer of Incidents'],'.')
